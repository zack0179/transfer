# %% [markdown]
# # JAM FITTER

# %%
# import sys,os
# sys.path.insert(0, "/group/JAM/webfitter/tmd/fitpack")
# os.environ['FITPACK']="/group/JAM/webfitter/tmd/fitpack"
# from fitlab.resman import RESMAN

# %%
import sys,os
from fitlab.resman import RESMAN
from fitlab.mcsamp import MCSAMP
from tools.config import load_config,conf
from tools.tools import load, save,checkdir
import pylab as py
import numpy as np
import pandas as pd
import copy

import matplotlib.pyplot as plt

def lprint(msg):
    sys.stdout.write('\r')
    sys.stdout.write('%s' %msg)
    sys.stdout.flush()
# %matplotlib inline

# %% [markdown]
# ## setup path to store the results

# %%
path2results='sia_collins_PionKaon1'
checkdir(path2results)

# %% [markdown]
# ## data sets

# %%
conf['datasets']={}

# %% [markdown]
# ## SIA

# %%
conf['datasets']['sia']={}
conf['datasets']['sia']['filters']={0:{'idx':None,'filter':None}}
conf['datasets']['sia']['filters'][0]['idx']=[1000,1001,1002,1003,1004,1005,2000,2002,2004,2005,2008,2009]
conf['datasets']['sia']['filters'][0]['filter']="Q2>1.69"
conf['datasets']['sia']['xlsx']={}
conf["datasets"]["sia"]["xlsx"][1000]="sia/expdata/1000.xlsx"  
conf["datasets"]["sia"]["xlsx"][1001]="sia/expdata/1001.xlsx"  
conf["datasets"]["sia"]["xlsx"][1002]="sia/expdata/1002.xlsx"  
conf["datasets"]["sia"]["xlsx"][1003]="sia/expdata/1003.xlsx"  
conf["datasets"]["sia"]["xlsx"][1004]="sia/expdata/1004.xlsx"  
conf["datasets"]["sia"]["xlsx"][1005]="sia/expdata/1005.xlsx"
conf["datasets"]["sia"]["xlsx"][2000]="sia/expdata/2000.xlsx"  
conf["datasets"]["sia"]["xlsx"][2002]="sia/expdata/2002.xlsx"
conf["datasets"]["sia"]["xlsx"][2004]="sia/expdata/2004.xlsx"  
conf["datasets"]["sia"]["xlsx"][2005]="sia/expdata/2005.xlsx"
conf["datasets"]["sia"]["xlsx"][2008]="sia/expdata/2008.xlsx"  
conf["datasets"]["sia"]["xlsx"][2009]="sia/expdata/2009.xlsx"
conf['datasets']['sia']['norm']={}
for k in conf['datasets']['sia']['xlsx']: 
    conf['datasets']['sia']['norm'][k]={'value':1,'fixed':True,'min':0,'max':1}

# %% [markdown]
# ## parameters

# %%
conf['params']={}
conf['shape']=1

# %% [markdown]
# ### TMD PDF/FF parameters (from upol analysis)

# %%
conf['params']={}
conf['params']['pdf']={}
conf['params']['pdf']['widths0 valence']  = {'value':5.89294556274006398056e-01,'fixed':True,'min':0,'max':1}
conf['params']['pdf']['widths0 sea']      = {'value':6.33443286558464269120e-01,'fixed':True,'min':0,'max':1}
conf['params']['ff']={}
conf['params']['ff']['widths0 pi+ fav']   = {'value':1.15151579728561548333e-01,'fixed':True,'min':0,'max':1}
conf['params']['ff']['widths0 pi+ unfav'] = {'value':1.36784756168045196212e-01,'fixed':True,'min':0,'max':1}
conf['params']['ff']['widths0 k+ fav']   = {'value':1.34062655687440246410e-01,'fixed':True,'min':0,'max':1}
conf['params']['ff']['widths0 k+ unfav'] = {'value':1.87915286213150012351e-01,'fixed':True,'min':0,'max':1}

# %% [markdown]
# ### TMD Collins parameters

# %%
conf['params']['collins']={}
conf['params']['collins']['widths0 pi+ fav']     = {'value':7.47958632885192820083e-02,'fixed':False,'min':0.05,'max':1.15151579728561548333e-01}
conf['params']['collins']['widths0 pi+ unfav']   = {'value':0.059763576917398841815e+00,'fixed':False,'min':0.05,'max':0.136784756168045196212}
conf['params']['collins']['widths0 k+ fav']     = {'value':1.71244211144534763669e-01,'fixed':False,'min':1e-5,'max':1.34062655687440246410e-01}
conf['params']['collins']['widths0 k+ unfav']   = {'value':1.13911942959768652806e-01,'fixed':False,'min':1e-5,'max':1.87915286213150012351e-01}

conf['params']['collins']['pi+ u N 1']  = {'value': 4.49239476315589936206e+00,'fixed':False,'min':0,'max':3}
conf['params']['collins']['pi+ u a 1']  = {'value':-8.28098465048009213518e-01,'fixed':False,'min':-1.9,'max':0}
conf['params']['collins']['pi+ u b 1']  = {'value': 6.60780815284983358282e+00,'fixed':False,'min':2,'max':6}

conf['params']['collins']['pi+ d N 1']  = {'value':-4.14852904854067539020e+00,'fixed':False,'min':-12,'max':0.0}
conf['params']['collins']['pi+ d a 1']  = {'value': 1.00000000000000000000e+00,'fixed':False,'min': 0,'max':7.0}
conf['params']['collins']['pi+ d b 1']  = {'value': 2.37348461151638101541e+00,'fixed':False,'min':2.5,'max':4.0}

conf['params']['collins']['pi+ u c 1']  = {'value': 0.0,'fixed':True,'min':-10,'max':10}
conf['params']['collins']['pi+ d c 1']  = {'value': 0.0,'fixed':True,'min':-10,'max':10}
conf['params']['collins']['pi+ u d 1']  = {'value': 0.0,'fixed':True,'min':-10,'max':10}
conf['params']['collins']['pi+ d d 1']  = {'value': 0.0,'fixed':True,'min':-10,'max':10}

conf['params']['collins']['pi+ u N 2']  = {'value': 6.11150078306284516572e+00,'fixed':False,'min':0,'max':15}
conf['params']['collins']['pi+ u a 2']  = {'value': 4.71508421683099232524e+00,'fixed':False,'min':1,'max':8.0}
conf['params']['collins']['pi+ u b 2']  = {'value': 2.75387728005980081392e+00,'fixed':False,'min':0,'max':5}

conf['params']['collins']['pi+ d N 2']  = {'value': 0.0,'fixed':True,'min':-20,'max':0}
conf['params']['collins']['pi+ d a 2']  = {'value': 0.0,'fixed':True,'min':-1,'max':5}
conf['params']['collins']['pi+ d b 2']  = {'value': 0.0,'fixed':True,'min':1e-5,'max':10}
conf['params']['collins']['pi+ u c 2']  = {'value': 0.0,'fixed':True,'min':-10,'max':10}
conf['params']['collins']['pi+ d c 2']  = {'value': 0.0,'fixed':True,'min':-10,'max':10}
conf['params']['collins']['pi+ u d 2']  = {'value': 0.0,'fixed':True,'min':-10,'max':10}
conf['params']['collins']['pi+ d d 2']  = {'value': 0.0,'fixed':True,'min':-10,'max':10}

conf['params']['collins']['k+ u N 1']  = {'value': 4.61030436110998920185e+00 ,'fixed':False,'min':-10,'max':10}
conf['params']['collins']['k+ u a 1']  = {'value': 3.16269974898406269759e+00 ,'fixed':False,'min':-1,'max':5}
conf['params']['collins']['k+ u b 1']  = {'value': 5.29693687388119904824e+00 ,'fixed':False,'min':1e-5,'max':10}
conf['params']['collins']['k+ u c 1']  = {'value': 0.00000000000000000000e+00 ,'fixed':True,'min':-10,'max':10}
conf['params']['collins']['k+ u d 1']  = {'value': 0.00000000000000000000e+00 ,'fixed':True,'min':-10,'max':10}

conf['params']['collins']['k+ d N 1']  = {'value':-1.28873046328637136382e-01 ,'fixed':False,'min':-10,'max':10}
conf['params']['collins']['k+ d a 1']  = {'value': 9.54509898128390599226e-01 ,'fixed':False,'min':-1,'max':5}
conf['params']['collins']['k+ d b 1']  = {'value': 2.95958582064559028169e+00 ,'fixed':False,'min':1e-5,'max':10}
conf['params']['collins']['k+ d c 1']  = {'value': 0.00000000000000000000e+00 ,'fixed':True,'min':-10,'max':10}
conf['params']['collins']['k+ d d 1']  = {'value': 0.00000000000000000000e+00 ,'fixed':True,'min':-10,'max':10}

# %% [markdown]
# ## Nested Sampling

# %% [markdown]
# ### initialize fitpack libraries

# %%
conf['ncpus']=1
conf['resman'] = RESMAN()
mcsamp=MCSAMP()
# Out:
# loading sia data sets 2009
# multiprocess setup: ncpus=1 / observable

# %% [markdown]
# ### start multiple NS runs
# - the code will start n independent runs specified by size

# %%
conf['size']=8
conf['factor']=3 # play with the factor (3,4) and the tolerance (1.e-5,1.e-10)
conf['tol']=1e-8
mcsamp.run(path2results)
# Out:
# iter=34947  logz=-23.278 rel-err=5.731e-06  t-elapsed=6.030e+04  dchi2min=2.488e+01 dchi2max=2.490e+01
# Process Process-6:
# Process Process-8:
# Process Process-3:
# Process Process-1:
# Process Process-7:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/apps/python/2.7.12/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#   File "/apps/python/2.7.12/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#   File "/apps/python/2.7.12/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#   File "/apps/python/2.7.12/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#   File "/apps/python/2.7.12/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#     self.run()
#     self.run()
#   File "/apps/python/2.7.12/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/apps/python/2.7.12/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self.run()
#     self.run()
#   File "/apps/python/2.7.12/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/apps/python/2.7.12/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#   File "/apps/python/2.7.12/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/mcsamp.py", line 83, in single_run
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/mcsamp.py", line 83, in single_run
#     results=nest.NEST().run()
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/mcsamp.py", line 83, in single_run
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/mcsamp.py", line 83, in single_run
#     results=nest.NEST().run()
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/mcsamp.py", line 83, in single_run
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/nest.py", line 406, in run
#     results=nest.NEST().run()
#     results=nest.NEST().run()
#     results=nest.NEST().run()
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/nest.py", line 406, in run
#     self.next(t2-t1)
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/nest.py", line 406, in run
#     self.next(t2-t1)
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/nest.py", line 406, in run
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/nest.py", line 361, in next
#     self.next(t2-t1)
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/nest.py", line 406, in run
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/nest.py", line 361, in next
#     self.next(t2-t1)
#     self.next(t2-t1)
#     self.gen_sample()
#     self.gen_sample()
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/nest.py", line 361, in next
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/nest.py", line 361, in next
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/nest.py", line 336, in gen_sample
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/nest.py", line 361, in next
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/nest.py", line 336, in gen_sample
#     _p,_nll=self.gen_par_cov(nll,p)
#     self.gen_sample()
#     self.gen_sample()
#     _p,_nll=self.gen_par_cov(nll,p)
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/nest.py", line 312, in gen_par_cov
#     self.gen_sample()
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/nest.py", line 312, in gen_par_cov
#     _nll = self.get_nll(p)
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/nest.py", line 336, in gen_sample
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/nest.py", line 336, in gen_sample
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/mcsamp.py", line 23, in nll
#     _nll = self.get_nll(p)
#     _p,_nll=self.gen_par_cov(nll,p)
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/nest.py", line 336, in gen_sample
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/nest.py", line 312, in gen_par_cov
#     res=self.get_residuals(par)
#     _nll = self.get_nll(p)
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/mcsamp.py", line 23, in nll
#     _p,_nll=self.gen_par_cov(nll,p)
#     _p,_nll=self.gen_par_cov(nll,p)
#     res=self.get_residuals(par)
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/mcsamp.py", line 23, in nll
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/mcsamp.py", line 14, in get_residuals
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/nest.py", line 300, in gen_par_cov
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/mcsamp.py", line 14, in get_residuals
#     res=self.get_residuals(par)
#     res,rres,nres=conf['resman'].get_residuals(par)
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/nest.py", line 312, in gen_par_cov
#     ellipse=ELLIPSE(self.active_p,conf['kappa'],self.cnt,conf['sample size'])
#     res,rres,nres=conf['resman'].get_residuals(par)
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/resman.py", line 110, in get_residuals
#     _nll = self.get_nll(p)
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/mcsamp.py", line 14, in get_residuals
#     if 'sia'     in conf['datasets']: res,rres,nres=self._get_residuals(self.siares.get_residuals,res,rres,nres)
#     res,rres,nres=conf['resman'].get_residuals(par)
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/resman.py", line 110, in get_residuals
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/mcsamp.py", line 23, in nll
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/nest.py", line 56, in __init__
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/resman.py", line 100, in _get_residuals
#     res=self.get_residuals(par)
#     if 'sia'     in conf['datasets']: res,rres,nres=self._get_residuals(self.siares.get_residuals,res,rres,nres)
#     _res,_rres,_nres=func()
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/resman.py", line 100, in _get_residuals
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/mcsamp.py", line 14, in get_residuals
#     self.det=np.linalg.det(cov)
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/resman.py", line 110, in get_residuals
#   File "/group/JAM/webfitter/tmd/fitpack/tools/residuals.py", line 178, in get_residuals
#     res,rres,nres=conf['resman'].get_residuals(par)
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/resman.py", line 110, in get_residuals
#     if 'sia'     in conf['datasets']: res,rres,nres=self._get_residuals(self.siares.get_residuals,res,rres,nres)
#     _res,_rres,_nres=func()
#   File "/apps/python/2.7.12/lib/python2.7/site-packages/numpy/linalg/linalg.py", line 1874, in det
#     self.get_theory()
#   File "/group/JAM/webfitter/tmd/fitpack/tools/residuals.py", line 178, in get_residuals
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/resman.py", line 100, in _get_residuals
#   File "/group/JAM/webfitter/tmd/fitpack/tools/residuals.py", line 164, in get_theory
#     if 'sia'     in conf['datasets']: res,rres,nres=self._get_residuals(self.siares.get_residuals,res,rres,nres)
#     output=self.mproc.run()
#   File "/group/JAM/webfitter/tmd/fitpack/fitlab/resman.py", line 100, in _get_residuals
#     r = _umath_linalg.det(a, signature=signature)
#     _res,_rres,_nres=func()
#     self.get_theory()
#   File "/group/JAM/webfitter/tmd/fitpack/tools/multiproc.py", line 38, in run
# KeyboardInterrupt
#     _res,_rres,_nres=func()
#   File "/group/JAM/webfitter/tmd/fitpack/tools/residuals.py", line 178, in get_residuals
#     return self.singlecore()
#   File "/group/JAM/webfitter/tmd/fitpack/tools/residuals.py", line 164, in get_theory
#   File "/group/JAM/webfitter/tmd/fitpack/tools/residuals.py", line 178, in get_residuals
#     self.get_theory()
#     output=self.mproc.run()
#     self.get_theory()
#   File "/group/JAM/webfitter/tmd/fitpack/tools/residuals.py", line 164, in get_theory
#   File "/group/JAM/webfitter/tmd/fitpack/tools/multiproc.py", line 24, in singlecore
#     return [self.func(entry) for entry in self.data]
#   File "/group/JAM/webfitter/tmd/fitpack/tools/residuals.py", line 164, in get_theory
#     output=self.mproc.run()
#   File "/group/JAM/webfitter/tmd/fitpack/tools/multiproc.py", line 38, in run
#     output=self.mproc.run()
#   File "/group/JAM/webfitter/tmd/fitpack/obslib/sia/residuals.py", line 69, in _get_theory
#   File "/group/JAM/webfitter/tmd/fitpack/tools/multiproc.py", line 38, in run
#     return self.singlecore()
#   File "/group/JAM/webfitter/tmd/fitpack/tools/multiproc.py", line 38, in run
#     return self.singlecore()
#   File "/group/JAM/webfitter/tmd/fitpack/tools/multiproc.py", line 24, in singlecore
#     return self.singlecore()
#     ZUuu =self.stfuncs.ZX(1,z1,z2,Q2,pT,h1+'+',h2+'-') + self.stfuncs.ZX(1,z1,z2,Q2,pT,h1+'-',h2+'+')
#   File "/group/JAM/webfitter/tmd/fitpack/tools/multiproc.py", line 24, in singlecore
#   File "/group/JAM/webfitter/tmd/fitpack/obslib/sia/stfuncs.py", line 79, in ZX
#     return [self.func(entry) for entry in self.data]
#   File "/group/JAM/webfitter/tmd/fitpack/tools/multiproc.py", line 24, in singlecore
#     return [self.func(entry) for entry in self.data]
#     return [self.func(entry) for entry in self.data]
#   File "/group/JAM/webfitter/tmd/fitpack/obslib/sia/residuals.py", line 58, in _get_theory
#   File "/group/JAM/webfitter/tmd/fitpack/obslib/sia/residuals.py", line 60, in _get_theory
#     Wq=self.get_Wq(z1,z2,k1,k2,hadron1,hadron2)
#     ZUuu =self.stfuncs.ZX(1,z1,z2,Q2,pT,h1+'+',h2+'-') + self.stfuncs.ZX(1,z1,z2,Q2,pT,h1+'-',h2+'+')
#   File "/group/JAM/webfitter/tmd/fitpack/obslib/sia/residuals.py", line 72, in _get_theory
#     ZUcol=self.stfuncs.ZX(2,z1,z2,Q2,pT,h1+'+',h2+'-') + self.stfuncs.ZX(2,z1,z2,Q2,pT,h1+'-',h2+'+')
#   File "/group/JAM/webfitter/tmd/fitpack/obslib/sia/stfuncs.py", line 79, in ZX
#   File "/group/JAM/webfitter/tmd/fitpack/obslib/sia/stfuncs.py", line 81, in ZX
#   File "/group/JAM/webfitter/tmd/fitpack/obslib/sia/stfuncs.py", line 64, in get_Wq
#     Wq=self.get_Wq(z1,z2,k1,k2,hadron1,hadron2)
#     ZLcol=self.stfuncs.ZX(2,z1,z2,Q2,pT,h1+'+',h2+'+') + self.stfuncs.ZX(2,z1,z2,Q2,pT,h1+'-',h2+'-')
#     K=self.get_K(i,z1,z2,pT,Wq,k1,k2,hadron1,hadron2)
#   File "/group/JAM/webfitter/tmd/fitpack/obslib/sia/stfuncs.py", line 60, in get_K
#   File "/group/JAM/webfitter/tmd/fitpack/obslib/sia/stfuncs.py", line 80, in ZX
#     +z2**2*conf[k2].widths[hadron1]\
#   File "/group/JAM/webfitter/tmd/fitpack/obslib/sia/stfuncs.py", line 63, in get_Wq
#     else: return 2.*self.Mh[hadron1]**2*z1**2/(np.pi*wq)
# KeyboardInterrupt
#     gauss=self.get_gauss(z1,z2,pT,k1,k2,Wq)
# KeyboardInterrupt
#     return ( z1**2*self.get_cc(conf[k1].widths[hadron2])\
#   File "/group/JAM/webfitter/tmd/fitpack/obslib/sia/stfuncs.py", line 69, in get_gauss
# KeyboardInterrupt
#     else: return np.ones(11)
#   File "/apps/python/2.7.12/lib/python2.7/site-packages/numpy/core/numeric.py", line 189, in ones
#     multiarray.copyto(a, 1, casting='unsafe')
# KeyboardInterrupt
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-10-aeeb08194c50> in <module>()
#       2 conf['factor']=3 # play with the factor (3,4) and the tolerance (1.e-5,1.e-10)
#       3 conf['tol']=1e-8
# ----> 4 mcsamp.run(path2results)
#
# /group/JAM/webfitter/tmd/fitpack/fitlab/mcsamp.pyc in run(self, path, size, factor)
#     107     P = [Process(target=self.single_run, args=('%s/%i.dat'%(outputdir,i),factor,)) for i  in nruns]
#     108     for p in P: p.start()
# --> 109     for p in P: p.join()
#     110
#     111   def get_MC_samples(self,mcpath):
#
# /apps/python/2.7.12/lib/python2.7/multiprocessing/process.pyc in join(self, timeout)
#     143         assert self._parent_pid == os.getpid(), 'can only join a child process'
#     144         assert self._popen is not None, 'can only join a started process'
# --> 145         res = self._popen.wait(timeout)
#     146         if res is not None:
#     147             _current_process._children.discard(self)
#
# /apps/python/2.7.12/lib/python2.7/multiprocessing/forking.pyc in wait(self, timeout)
#     152         def wait(self, timeout=None):
#     153             if timeout is None:
# --> 154                 return self.poll(0)
#     155             deadline = time.time() + timeout
#     156             delay = 0.0005
#
# /apps/python/2.7.12/lib/python2.7/multiprocessing/forking.pyc in poll(self, flag)
#     133                 while True:
#     134                     try:
# --> 135                         pid, sts = os.waitpid(self.pid, flag)
#     136                     except os.error as e:
#     137                         if e.errno == errno.EINTR:
#
# KeyboardInterrupt:

# %% [markdown]
# ### combine multiple runs into one big run

# %%
MC=mcsamp.get_MC_samples(path2results+'/mcdata')
# Out:
# runs max likelihoods
# 9.555293950868048
# 7.6328581148893875
# 12.386622373852646
# sample  size= 42008
# sample2 size= 1563

# %% [markdown]
# ### distribution of parameters

# %%
os.listdir(path2results+'/mcdata')
# Out:
# ['4.dat', '3.dat', '1.dat']

# %%
samples=MC['samples']
samples2=MC['samples2']
weights=MC['weights']
weights2=MC['weights2']
order=MC['order']
runs=MC['runs']

nrows,ncols=10,4
fig = py.figure(figsize=(ncols*4,nrows*2))

def get_idx(key,tag):
    for i in range(len(order)):
        if order[i][1]==key and order[i][2]==tag:
            return i

global cnt
cnt=0
def plot(tags):
    global cnt
    for i in range(1,len(tags)):
        cnt+=1
        if tags[i]==None: continue
        idx=get_idx(tags[0],tags[i])
        ax=py.subplot(nrows,ncols,cnt)
        vmin=np.amin(samples2.T[idx])
        vmax=np.amax(samples2.T[idx])
        R=None#(vmin,vmax)
        for k in runs:
            ax.hist(runs[k]['samples'].T[idx],weights=runs[k]['weights'],bins=50,normed=True,range=R)
        ax.hist(samples.T[idx],weights=weights,bins=50,color='k',normed=True,range=R)
        ax.hist(samples2.T[idx],weights=weights2,bins=50,color='r',histtype='step',normed=True,range=R)
        ax.set_title(tags[i])
        mean=np.einsum('i,i',samples2.T[idx],weights2)
        std=np.einsum('i,i',(samples2.T[idx]-mean)**2,weights2)**0.5
        print '%20s = %10.5f +/- %10.5f'%(tags[i],mean,std)
        #ax.set_xlim(vmin,vmax)
    py.tight_layout()

plot(['collins','widths0 pi+ fav','widths0 pi+ unfav',None])
plot(['collins','pi+ u N 1','pi+ u a 1','pi+ u b 1'])
plot(['collins','pi+ d N 1','pi+ d a 1','pi+ d b 1'])
plot(['collins','pi+ u N 2','pi+ u a 2','pi+ u b 2'])
plot(['collins','widths0 k+ fav','widths0 k+ unfav',None])
plot(['collins','k+ u N 1','k+ u a 1','k+ u b 1'])
plot(['collins','k+ d N 1','k+ d a 1','k+ d b 1'])
# Out:
#      widths0 pi+ fav =    0.07160 +/-    0.00145
#    widths0 pi+ unfav =    0.12355 +/-    0.01085
#            pi+ u N 1 =    1.13412 +/-    0.14508
#            pi+ u a 1 =   -1.49854 +/-    0.06182
#            pi+ u b 1 =    4.72006 +/-    0.18722
#            pi+ d N 1 =   -6.40350 +/-    1.30864
#            pi+ d a 1 =    3.81163 +/-    0.40471
#            pi+ d b 1 =    3.06247 +/-    0.13422
#            pi+ u N 2 =    9.51040 +/-    1.65919
#            pi+ u a 2 =    3.71686 +/-    0.71486
#            pi+ u b 2 =    3.76305 +/-    0.16649
#       widths0 k+ fav =    0.11298 +/-    0.01229
#     widths0 k+ unfav =    0.10627 +/-    0.02860
#             k+ u N 1 =    4.02264 +/-    1.57602
#             k+ u a 1 =    1.59274 +/-    1.58658
#             k+ u b 1 =    8.46328 +/-    1.93776
#             k+ d N 1 =   -4.58946 +/-    1.36972
#             k+ d a 1 =    3.53922 +/-    1.64712
#             k+ d b 1 =    6.22681 +/-    1.66427

# %% [markdown]
# ## data vs theory

# %%
data={'weights':MC['weights2']}
cnt=0
for s in MC['samples2']:
    cnt+=1    
    lprint('%d/%d'%(cnt,len(MC['samples2'])))  
    conf['resman'].get_residuals(s);
    for k in conf['resman'].siares.tabs:
        if k  not in data: data[k]=[]
        thy=conf['resman'].siares.tabs[k]['thy']    
        norm=conf['datasets']['sia']['norm'][k]['value']
        shift=conf['resman'].siares.tabs[k]['shift']        
        data[k].append(shift+thy/norm)
save(data,'%s/%s'%(path2results,'sia.dat'))
# Out:
# 1563/1563

# %% [markdown]
# ### compute averages and collect results

# %%
data=load('%s/%s'%(path2results,'sia.dat'))   
for k in data: data[k]=np.array(data[k])
thy,dthy={},{}
for k in data:
    if k=='weights': continue
    thy[k]=np.einsum('i,ik->k',data['weights'],data[k])
    dthy[k]=np.einsum('i,ik->k',data['weights'],(data[k]-thy[k])**2)**0.5
for k in thy: 
    conf['resman'].siares.tabs[k]['thy']=copy.copy(thy[k])
    conf['resman'].siares.tabs[k]['dthy']=copy.copy(dthy[k])

# %%
report=conf['resman'].gen_report(verb=0,level=1)
delimiters=[]
for i in range(len(report)): 
    if 'reaction:' in report[i]: 
        delimiters.append(i) 

data={}
nlines=len(report)
for i in range(len(delimiters)):
    ini=delimiters[i]
    if i==len(delimiters)-1: fin=len(report)
    else: fin=delimiters[i+1]
    reaction=report[ini].replace('reaction:','').strip()
    data[reaction]={'raw data':report[ini:fin]}
    
for k in data:
    print k
    block=data[k]['raw data']
    isep=[i for i in range(len(block)) if '--------' in block[i]][0]
    data[k]['summary']=[block[i] for i in range(isep)]
    data[k]['tables']=[block[i] for i in range(isep+1,len(block))]

    tabs={}
    for l in data[k]['tables']:
        info=l.split(',')
        col=[s for s in info if 'col' in s][0].split('=')[1].strip()
        if col not in tabs: tabs[col]={}
        info=[[ss.strip() for ss in s.split('=')] for s in info if 'col' not in info  if s.strip()!='']
        
        for s in info:
            if s[0] not in tabs[col]: tabs[col][s[0]]=[]
        
        for s in info:
            try:
                value=float(s[1])
            except:
                value=s[1]
            tabs[col][s[0]].append(value)        

    data[k]['tabs']=tabs
save(data,'%s/%s'%(path2results,'data_and_thy.dat'))
# Out:
# sia

# %%
def summary():
    for k in data:
        print ""
        for l in data[k]['summary']: print l
summary()
# Out:
# reaction: sia
#    1000      BaBaR     9      21.03       0.00       0.00
#    1001      BaBaR     9      12.36       0.00       0.00
#    1002      BaBaR    36       9.59       0.00       0.00
#    1003      BaBaR    36      22.85       0.00       0.00
#    1004      belle    16      12.95       0.00       0.00
#    1005      belle    16      13.23       0.00       0.00
#    2000      BaBaR    16     101.18       0.00       0.00
#    2002      BaBaR    16      17.63       0.00       0.00
#    2004      BaBaR    16      19.09       0.00       0.00
#    2005      BaBaR    16       8.55       0.00       0.00
#    2008      BaBaR    16      15.76       0.00       0.00
#    2009      BaBaR    16       4.65       0.00       0.00

# %% [markdown]
# ### plot data and theory

# %%
ALL=pd.concat([pd.DataFrame(conf['resman'].siares.tabs[idx]) \
              for idx in conf['resman'].siares.tabs.keys()])

ALL.columns
# Out:
# Index([          u'N',           u'Q',          u'Q2',     u'S2/1+C2',
#            u'S2/1-C2',       u'Shift',       u'alpha',         u'col',
#           u'dS2/1-C2',         u'dqT',        u'dthy',         u'dz1',
#                u'dz2',     u'hadron1',     u'hadron2',           u'i',
#                u'obs',          u'pT',       u'pTmax',       u'pTmin',
#                 u'qT', u'r-residuals',   u'residuals',       u'shift',
#             u'stat_u',       u'sys_u',       u'syt_u',         u'thy',
#              u'value',          u'z1',       u'z1max',       u'z1min',
#                 u'z2',       u'z2max',       u'z2min'],
#       dtype='object')

# %%
data = {}

for key, value in conf['resman'].siares.tabs.iteritems():
    data[key] = pd.DataFrame(value)

# %%
# from the paper https://arxiv.org/pdf/1309.5278.pdf
z1_bins = np.array([0.15, 0.2, 0.3, 0.4, 0.5, 0.7, 0.9])

# %%
def plot(data1, data2, 
         label1='dataset 1', label2='dataset 2'):

    n_col = 3
    n_row = len(z1_bins)/n_col + 1

    plt.figure(figsize=(4 *n_col, 3 *n_row))

    for index in range(len(z1_bins)-1):
        data_sub1 = data1.query('z1 > %f and z1 < %f' % (z1_bins[index], z1_bins[index+1]))
        data_sub2 = data2.query('z1 > %f and z1 < %f' % (z1_bins[index], z1_bins[index+1]))

        plt.subplot(n_row, n_col, index+1)
        plt.errorbar(data_sub1.z2, data_sub1.value, data_sub1.alpha, 
                    marker='o', linestyle='', color='red', label=label1)
        plt.plot(data_sub1.z2, data_sub1.thy, linestyle='-', color='red')
        plt.fill_between(data_sub1.z2, data_sub1.thy-data_sub1.dthy, data_sub1.thy+data_sub1.dthy,
                         color='red', alpha=0.4)


        plt.errorbar(data_sub2.z2, data_sub2.value, data_sub2.alpha, 
                    marker='o', linestyle='', color='blue', label=label2)
        plt.plot(data_sub2.z2, data_sub2.thy, linestyle='-', color='blue')
        plt.fill_between(data_sub2.z2, data_sub2.thy-data_sub2.dthy, data_sub2.thy+data_sub2.dthy, 
                         color='blue', alpha=0.4)
        
        plt.xlim([0.0, 1.0])
        plt.xlabel('$Z_2$')
        plt.title('$Z_1 \in [%.1f, %.1f]$' % (z1_bins[index], z1_bins[index+1]))
        
        # the legend has theory labels and I dont like them.
        if len(data_sub1) > 0 and len(data_sub2) > 0:
            handles, labels = plt.gca().get_legend_handles_labels()
            good_handles = []
            good_labels = []
            for handle, label in zip(handles, labels):
                if 'thy' not in label:
                    good_handles.append(handle)
                    good_labels.append(label)
            
            plt.legend(good_handles, good_labels, frameon=False, loc='topleft')
        
    plt.tight_layout()

# %%
for key, value in data.iteritems():
    print(key, np.unique(value.obs))
# Out:
# (1000, array([u'AUL-0-PT'], dtype=object))
# (1001, array([u'AUC-0-PT'], dtype=object))
# (1002, array([u'AUC-0-PT-INT'], dtype=object))
# (1003, array([u'AUL-0-PT-INT'], dtype=object))
# (1004, array([u'AUC-0-PT-INT'], dtype=object))
# (1005, array([u'AUL-0-PT-INT'], dtype=object))
# (2000, array([u'AUL-0-PT-INT'], dtype=object))
# (2002, array([u'AUC-0-PT-INT'], dtype=object))
# (2004, array([u'AUL-0-PT-INT'], dtype=object))
# (2005, array([u'AUC-0-PT-INT'], dtype=object))
# (2008, array([u'AUL-0-PT-INT'], dtype=object))
# (2009, array([u'AUC-0-PT-INT'], dtype=object))

# %%
plot(data[1002], data[1003], '$A_{UC}$', '$A_{UL}$')

# %%
plot(data[1004], data[1005], '$A_{UC}$', '$A_{UL}$')

# %%
plot(data[2009], data[2008], '$A_{UC}$', '$A_{UL}$')

# %%
plot(data[2002], data[2000], '$A_{UC}$', '$A_{UL}$') #ka-ka

# %%
plot(data[2005], data[2004], '$A_{UC}$', '$A_{UL}$') #pi-ka

# %%
def plot_pt(data1, data2, 
            label1='dataset1', label2='dataset 2'):

    plt.errorbar(data1.pT, 
                 data1.value, 
                 data1.alpha,
            linestyle='', marker='o', color='red',
                label=label1)
    
    plt.plot(data1.pT, 
             data1.thy, 
             linestyle='-', color='red')
    
    plt.fill_between(data1.pT, data1.thy-data1.dthy, data1.thy+data1.dthy, 
                             color='red', alpha=0.4)

    plt.errorbar(data2.pT, 
                 data2.value, 
                 data2.alpha,
            linestyle='', marker='o', color='blue',
                label=label2)

    plt.plot(data2.pT, 
             data2.thy, 
             linestyle='-', color='blue')
    
    plt.fill_between(data2.pT, data2.thy-data2.dthy, data2.thy+data2.dthy, 
                             color='blue', alpha=0.4)
    
    # the legend has theory labels and I dont like them.
    if len(data1) > 0 and len(data2) > 0:
        handles, labels = plt.gca().get_legend_handles_labels()
        good_handles = []
        good_labels = []
        
        for handle, label in zip(handles, labels):
            if 'thy' not in label:
                good_handles.append(handle)
                good_labels.append(label)
    
    plt.legend(good_handles, good_labels, frameon=False)
    plt.xlabel('$P_{T}$')

# %%
plot_pt(data[1000], data[1001], '$A_{UL}$', '$A_{UC}$')

# %% [markdown]
# ## PDFs and FFs

# %%
def calc(func):
    RAW=[]
    cnt=0
    for s in MC['samples2']:
        cnt+=1    
        lprint('%d/%d'%(cnt,len(MC['samples2'])))  
        conf['parman'].set_new_params(s);    
        RAW.append(func())
    RAW=np.array(RAW)
    f =np.einsum('k,kif->if',MC['weights2'],RAW)
    df=np.einsum('k,kif->if',MC['weights2'],(RAW-f)**2)**0.5
    f=np.einsum('if->fi',f)
    df=np.einsum('if->fi',df)
    return {'f':f,'df':df}

# %%
Z1=10**np.linspace(-4,-2)
Z2=np.linspace(0.0101,0.999)
Z=np.append(Z1,Z2)
Hpi=calc(lambda : [conf['collins'].get_C(z,1,'pi+') for z in Z])
Hka=calc(lambda : [conf['collins'].get_C(z,1,'k+') for z in Z])
# Out:
# 1563/1563

# %%
nrows,ncols=1,2
py.figure(figsize=(ncols*5,nrows*5))
ax=py.subplot(nrows,ncols,1)
ax.fill_between(Z,Z*(Hpi['f'][1]-Hpi['df'][1]),Z*(Hpi['f'][1]+Hpi['df'][1]),color='r',alpha=0.5)
ax.fill_between(Z,Z*(Hpi['f'][3]-Hpi['df'][3]),Z*(Hpi['f'][3]+Hpi['df'][3]),color='b',alpha=0.5)
ax.plot(Z,Z*0,'black')
ax.plot(Z,Z*Hpi['f'][1],'r')
ax.plot(Z,Z*Hpi['f'][3],'b')
ax.set_ylabel(r'$z H_1^{\perp (1)}(z)$',size=20)
ax.set_xlabel(r'$z$',size=20)
ax.set_ylim(-0.2,1.5)
ax.set_xlim(0,1)


py.tight_layout()

# %%
nrows,ncols=1,2
py.figure(figsize=(ncols*5,nrows*5))
ax=py.subplot(nrows,ncols,1)
ax.fill_between(Z,Z*(Hka['f'][1]-Hka['df'][1]),Z*(Hka['f'][1]+Hka['df'][1]),color='r',alpha=0.5)
ax.fill_between(Z,Z*(Hka['f'][3]-Hka['df'][3]),Z*(Hka['f'][3]+Hka['df'][3]),color='b',alpha=0.5)
ax.plot(Z,Z*0,'black')
ax.plot(Z,Z*Hka['f'][1],'r')
ax.plot(Z,Z*Hka['f'][3],'b')
ax.set_ylabel(r'$z H_1^{\perp (1)}(z)$',size=20)
ax.set_xlabel(r'$z$',size=20)
ax.set_ylim(-0.1,0.1)
ax.set_xlim(0,1)


py.tight_layout()
